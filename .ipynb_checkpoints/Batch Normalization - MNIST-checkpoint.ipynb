# %%
import cPickle
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Image
from scipy import ndimage
from sklearn import preprocessing

# Config the matlotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
with open("F:\DataAnalysis&MachineLearning\ResearchAttempt\WorkWithIan\Dataset\mnist.pkl",'rb') as mnist_file:
    train_data,valid_data,test_data = cPickle.load(mnist_file)

# %%
## In this block we are shuffling the data to avoid any classification bias
train_vec_in,train_label_out = train_data
permutation = np.random.permutation(train_vec_in.shape[0])
train_vec_in = train_vec_in[permutation,:]
train_reshape = np.reshape(train_vec_in,newshape=[50000,28,28])
train_label_out = train_label_out[permutation]

plt.imshow(train_reshape[3],cmap='gray')
print train_label_out[3]
# Out:
# 5

# %%
valid_features,valid_labels = valid_data
test_features,test_labels = test_data

# %%
def confusion_matrix(predicted_outcome,labels):
    classes = set(labels)
    num_classes = len(classes)
    conf_mat = np.zeros((num_classes,num_classes))
    for i in classes:
        for j in classes:
            conf_mat[i,j] = len(np.where((labels == i) & (predicted_outcome == j))[0])
    
    false_positives = np.sum(conf_mat,axis=0)
    false_negatives = np.sum(conf_mat,axis=1)
    precision = np.array([conf_mat[i,i]/false_positives[i] for i in range(10)])
    recall = np.array([conf_mat[i,i]/false_negatives[i] for i in range(10)])
    return precision,recall

# %%
def two_layer_nn_sgd(features,labels,valid_features,valid_labels,hidden_sz=100, \
                     batch_size=200,epoch=10,lamda=0.001,step_size=1,max_iter=100):
    features_dim= np.shape(features)
    classes = set(labels)
    coeff_1 = 0.01 * np.random.randn(features_dim[1],hidden_sz)/(np.sqrt(features_dim[1]))
    coeff_2 = 0.01 * np.random.randn(hidden_sz,len(classes))/(np.sqrt(hidden_sz))

    tot_cost,train_accuracy,valid_accuracy = [],[],[]
    coeff1_dim = np.shape(coeff_1)    
    coeff2_dim = np.shape(coeff_2)
    bias_1 = 0.01 * np.random.randn(1,coeff1_dim[1])
    bias_2 = 0.01 * np.random.randn(1,coeff2_dim[1])
    #bias_1 = np.zeros((1,coeff1_dim[1]))
    #bias_2 = np.zeros((1,coeff2_dim[1]))

    print 'Training model for batch_size:%d, lamda:%.4f, and step_size: %.4f' % (batch_size,lamda,step_size)
    num_batches = features_dim[0]/batch_size
    
    for _ in xrange(epoch):
        for i in xrange(num_batches):
            batch_features = features[i*batch_size:(i+1)*batch_size]
            batch_dim = np.shape(batch_features)
            batch_labels = labels[i*batch_size:(i+1)*batch_size]
            batch_labels_dim = np.shape(batch_labels)
            
            #### Layer - 1 ####
            reLU = np.maximum(0,np.dot(batch_features,coeff_1) + bias_1)   # reLU - shape (Nxh)

            ## without equalization ##
            #l2_scores = np.dot(reLU,coeff_2) + bias_2  # [NxK]
            #exp_scores = np.exp(l2_scores)
            #probs_scores = exp_scores/np.sum(exp_scores,axis=1,keepdims=True)  # probs - shape(NxK)

            ## with max-equalization ##
            l2_scores = np.transpose(np.dot(reLU,coeff_2) + bias_2) # [KxN]
            l2_scores_max = np.max(l2_scores,axis=0) # [1xN]
            exp_scores = np.exp(l2_scores-l2_scores_max)
            probs_scores = exp_scores/np.sum(exp_scores,axis=0,keepdims=True)  # probs - shape(KxN)
            
            ## Loss computation
            tot_cost.append(-np.sum(probs_scores[batch_labels,range(batch_dim[0])])/batch_dim[0])
        
            # backpropagation
            probs = np.transpose(probs_scores) # shape - NxK
            probs[range(batch_dim[0]),batch_labels] -= 1
            probs /= batch_dim[0]

            dcoeff_2 = np.dot(reLU.T,probs)   # dcoeff_2 - shape(hxK)
            dbias_2 = np.sum(probs, axis=0, keepdims=True)
            dhidden_layer = np.dot(probs,coeff_2.T)   # dhidden - shape(Nxh)
            dhidden_layer[reLU <= 0] = 0
            dcoeff_1 = np.dot(batch_features.T,dhidden_layer)
            dbias_1 = np.sum(dhidden_layer, axis=0, keepdims=True)

            coeff_2 += -step_size*(dcoeff_2 + lamda*coeff_2)  # coeff_2 - shape(hxK)
            coeff_1 += -step_size*(dcoeff_1 + lamda*coeff_1)  # coeff_1 - shape(Dxh)
            bias_1 += -step_size * dbias_1
            bias_2 += -step_size * dbias_2
            
            hidden_layer_train = np.maximum(0,np.dot(features,coeff_1)+bias_1)
            scores_train = np.dot(hidden_layer_train,coeff_2)+bias_2
            predicted_class_train = np.argmax(scores_train, axis=1)
            train_accuracy.append(np.mean(predicted_class_train == labels))
        
            hidden_layer_valid = np.maximum(0,np.dot(valid_features,coeff_1)+bias_1)
            scores_valid = np.dot(hidden_layer_valid,coeff_2)+bias_2
            predicted_class_valid = np.argmax(scores_valid,axis=1)
            valid_accuracy.append(np.mean(predicted_class_valid == valid_labels))
        
    ##### Training Data accuracy #####
    hidden_layer_train = np.maximum(0,np.dot(features,coeff_1)+bias_1)
    scores_train = np.dot(hidden_layer_train,coeff_2)+bias_2
    predicted_class_train = np.argmax(scores_train, axis=1)
    print 'training accuracy: %.4f' % (np.mean(predicted_class_train == labels))
    precision_train,recall_train = confusion_matrix(predicted_class_train,labels)
    print 'training mean precision: %.4f, mean recall: %.4f' % (np.mean(precision_train),np.mean(recall_train))

    ##### Validation Data accuracy #####
    hidden_layer_valid = np.maximum(0,np.dot(valid_features,coeff_1)+bias_1)
    scores_valid = np.dot(hidden_layer_valid,coeff_2)+bias_2
    predicted_class_valid = np.argmax(scores_valid,axis=1)
    print 'validation accuracy: %.4f' % (np.mean(predicted_class_valid == valid_labels))
    precision_valid,recall_valid = confusion_matrix(predicted_class_valid,valid_labels)
    print 'validation mean precision: %.4f, mean recall: %.4f' % (np.mean(precision_valid),np.mean(recall_valid))   
        
    return coeff_1,bias_1,coeff_2,bias_2,tot_cost,train_accuracy,valid_accuracy

# %%
coeff_1,bias_1,coeff_2,bias_2,tot_cost,train_accuracy,valid_accuracy = two_layer_nn_sgd(train_vec_in,train_label_out, \
                                                valid_features,valid_labels, \
                                           epoch=20,hidden_sz=200,lamda=0.0001,step_size=0.75,max_iter=1000)

##### Test Data accuracy #####
hidden_layer_test = np.maximum(0,np.dot(test_features,coeff_1)+bias_1)
scores_test = np.dot(hidden_layer_test,coeff_2)+bias_2
predicted_class_test = np.argmax(scores_test,axis=1)
print 'test accuracy: %.4f' % (np.mean(predicted_class_test == test_labels))
precision_test,recall_test= confusion_matrix(predicted_class_test,test_labels)
print 'test mean precision: %.4f, mean recall: %.4f' % (np.mean(precision_test),np.mean(recall_test))
# Out:
# Training model for batch_size:200, lamda:0.0001, and step_size: 0.7500
# training accuracy: 0.9955
# training mean precision: 0.9955, mean recall: 0.9955
# validation accuracy: 0.9765
# validation mean precision: 0.9766, mean recall: 0.9763
# test accuracy: 0.9758
# test mean precision: 0.9758, mean recall: 0.9756

# %%
plt.figure()
plt.plot(train_accuracy,'r')
plt.plot(valid_accuracy,'b')
plt.show()

# %%
## Measuring impact of step size on convergence.
step_size = np.logspace(-1,0.0,num=10)

for elem in step_size:
    print 'Running Iteration with step size: %d'%elem
    coeff_1,bias_1,coeff_2,bias_2,tot_cost = two_layer_nn_sgd(train_vec_in,train_label_out,valid_features,valid_labels, \
                                           epoch=20,hidden_sz=200,lamda=0.0005,step_size=elem,max_iter=1000)
    plt.plot(tot_cost)
    plt.show()
# Out:
# Running Iteration with step size: 0
# Training model for batch_size:200, lamda:0.0005, and step_size: 0.1000
# training accuracy: 0.9671
# training mean precision: 0.9670, mean recall: 0.9669
# validation accuracy: 0.9657
# validation mean precision: 0.9656, mean recall: 0.9654
# Running Iteration with step size: 0
# Training model for batch_size:200, lamda:0.0005, and step_size: 0.1292
# training accuracy: 0.9740
# training mean precision: 0.9740, mean recall: 0.9739
# validation accuracy: 0.9683
# validation mean precision: 0.9682, mean recall: 0.9681
# Running Iteration with step size: 0
# Training model for batch_size:200, lamda:0.0005, and step_size: 0.1668
# training accuracy: 0.9790
# training mean precision: 0.9790, mean recall: 0.9788
# validation accuracy: 0.9718
# validation mean precision: 0.9718, mean recall: 0.9716
# Running Iteration with step size: 0
# Training model for batch_size:200, lamda:0.0005, and step_size: 0.2154
# training accuracy: 0.9831
# training mean precision: 0.9832, mean recall: 0.9830
# validation accuracy: 0.9735
# validation mean precision: 0.9734, mean recall: 0.9732
# Running Iteration with step size: 0
# Training model for batch_size:200, lamda:0.0005, and step_size: 0.2783
# training accuracy: 0.9860
# training mean precision: 0.9860, mean recall: 0.9859
# validation accuracy: 0.9762
# validation mean precision: 0.9761, mean recall: 0.9760
# Running Iteration with step size: 0
# Training model for batch_size:200, lamda:0.0005, and step_size: 0.3594
# training accuracy: 0.9881
# training mean precision: 0.9881, mean recall: 0.9880
# validation accuracy: 0.9757
# validation mean precision: 0.9757, mean recall: 0.9755
# Running Iteration with step size: 0
# Training model for batch_size:200, lamda:0.0005, and step_size: 0.4642
# training accuracy: 0.9900
# training mean precision: 0.9900, mean recall: 0.9899
# validation accuracy: 0.9788
# validation mean precision: 0.9788, mean recall: 0.9786
# Running Iteration with step size: 0
# Training model for batch_size:200, lamda:0.0005, and step_size: 0.5995
# training accuracy: 0.9898
# training mean precision: 0.9899, mean recall: 0.9898
# validation accuracy: 0.9771
# validation mean precision: 0.9772, mean recall: 0.9769
# Running Iteration with step size: 0
# Training model for batch_size:200, lamda:0.0005, and step_size: 0.7743
# training accuracy: 0.9901
# training mean precision: 0.9902, mean recall: 0.9900
# validation accuracy: 0.9770
# validation mean precision: 0.9771, mean recall: 0.9767
# Running Iteration with step size: 1
# Training model for batch_size:200, lamda:0.0005, and step_size: 1.0000
# training accuracy: 0.9864
# training mean precision: 0.9865, mean recall: 0.9864
# validation accuracy: 0.9739
# validation mean precision: 0.9739, mean recall: 0.9735

# %%
## Here'll along with plotting the tot_cost, we'll also plot the accuracy
# over training and validation sets to see how the step_size affects over epochs
step_size = np.logspace(-1,0.0,num=5)

for elem in step_size:
    print 'Running Iteration with step size: %d'%elem
    coeff_1,bias_1,coeff_2,bias_2,tot_cost,train_accuracy,valid_accuracy = two_layer_nn_sgd(train_vec_in,train_label_out, \
                                                                                            valid_features,valid_labels, \
                                           epoch=5,hidden_sz=200,lamda=0.0005,step_size=elem,max_iter=1000)
    plt.plot(tot_cost)
    plt.show()
    plt.plot(train_accuracy)
    plt.show()
    plt.plot(valid_accuracy)
    plt.show()
# Out:
# Running Iteration with step size: 0
# Training model for batch_size:200, lamda:0.0005, and step_size: 0.1000
# training accuracy: 0.9209
# training mean precision: 0.9201, mean recall: 0.9199
# validation accuracy: 0.9261
# validation mean precision: 0.9258, mean recall: 0.9253
# Running Iteration with step size: 0
# Training model for batch_size:200, lamda:0.0005, and step_size: 0.1778
# training accuracy: 0.9427
# training mean precision: 0.9423, mean recall: 0.9422
# validation accuracy: 0.9473
# validation mean precision: 0.9472, mean recall: 0.9469
# Running Iteration with step size: 0
# Training model for batch_size:200, lamda:0.0005, and step_size: 0.3162
# training accuracy: 0.9613
# training mean precision: 0.9612, mean recall: 0.9611
# validation accuracy: 0.9618
# validation mean precision: 0.9616, mean recall: 0.9615
# Running Iteration with step size: 0
# Training model for batch_size:200, lamda:0.0005, and step_size: 0.5623
# training accuracy: 0.9755
# training mean precision: 0.9755, mean recall: 0.9754
# validation accuracy: 0.9717
# validation mean precision: 0.9716, mean recall: 0.9714
# Running Iteration with step size: 1
# Training model for batch_size:200, lamda:0.0005, and step_size: 1.0000
# training accuracy: 0.9744
# training mean precision: 0.9745, mean recall: 0.9742
# validation accuracy: 0.9675
# validation mean precision: 0.9676, mean recall: 0.9671

# %% [markdown]
# ## Cross Validation Hyperparameter Optimization

# %%
def two_layer_nn_sgd_cv(features,labels,hidden_sz=100,cross_valid_k=6, \
                     batch_size=200,epoch=10,lamda=0.001,step_size=1,max_iter=100):
    ''' Using Cross validation for Hyperparameter Optimization. 
    For MNIST, the training set consists of 50000 labels and validation
    set consists of 10000 labels. 
    The input to this should be a dataset comprising of training + validation set.
    That gives a input dataset of 60000.'''
    features_dim= np.shape(features)
    classes = set(labels)
    tot_cost = []
    accuracy = 0.0

    print '------ Training model for batch_size:%d, lamda:%.4f, and step_size: %.4f ------' % (batch_size,lamda,step_size)
    num_batches = features_dim[0]/batch_size
    size_per_valid_set = features_dim[0]/cross_valid_k
    
    for j in xrange(cross_valid_k):
        print "-------------- cross validating set %d --------------"%j
        
        coeff_1 = 0.01 * np.random.randn(features_dim[1],hidden_sz)/(np.sqrt(features_dim[1]))
        coeff_2 = 0.01 * np.random.randn(hidden_sz,len(classes))/(np.sqrt(hidden_sz))
        coeff1_dim = np.shape(coeff_1)    
        coeff2_dim = np.shape(coeff_2)
        bias_1 = 0.01 * np.random.randn(1,coeff1_dim[1])
        bias_2 = 0.01 * np.random.randn(1,coeff2_dim[1])        
        
        valid_features = features[j*10000:(j+1)*10000]
        valid_labels = labels[j*10000:(j+1)*10000]
        training_features = np.delete(features,np.s_[j*10000:(j+1)*10000],axis=0)
        training_labels = np.delete(labels,np.s_[j*10000:(j+1)*10000],axis=0)
    
        for _ in xrange(epoch):
            for i in xrange(num_batches):
                batch_features = training_features[i*batch_size:(i+1)*batch_size]
                batch_dim = np.shape(batch_features)
                batch_labels = training_labels[i*batch_size:(i+1)*batch_size]
                batch_labels_dim = np.shape(batch_labels)

                #### Layer - 1 ####
                reLU = np.maximum(0,np.dot(batch_features,coeff_1) + bias_1)   # reLU - shape (Nxh)

                ## without equalization ##
                #l2_scores = np.dot(reLU,coeff_2) + bias_2  # [NxK]
                #exp_scores = np.exp(l2_scores)
                #probs_scores = exp_scores/np.sum(exp_scores,axis=1,keepdims=True)  # probs - shape(NxK)

                ## with max-equalization ##
                l2_scores = np.transpose(np.dot(reLU,coeff_2) + bias_2) # [KxN]
                l2_scores_max = np.max(l2_scores,axis=0) # [1xN]
                exp_scores = np.exp(l2_scores-l2_scores_max)
                probs_scores = exp_scores/np.sum(exp_scores,axis=0,keepdims=True)  # probs - shape(KxN)

                ## Loss computation
                tot_cost.append(-np.sum(probs_scores[batch_labels,range(batch_dim[0])])/batch_dim[0])

                # backpropagation
                probs = np.transpose(probs_scores) # shape - NxK
                probs[range(batch_dim[0]),batch_labels] -= 1
                probs /= batch_dim[0]

                dcoeff_2 = np.dot(reLU.T,probs)   # dcoeff_2 - shape(hxK)
                dbias_2 = np.sum(probs, axis=0, keepdims=True)
                dhidden_layer = np.dot(probs,coeff_2.T)   # dhidden - shape(Nxh)
                dhidden_layer[reLU <= 0] = 0
                dcoeff_1 = np.dot(batch_features.T,dhidden_layer)
                dbias_1 = np.sum(dhidden_layer, axis=0, keepdims=True)

                coeff_2 += -step_size*(dcoeff_2 + lamda*coeff_2)  # coeff_2 - shape(hxK)
                coeff_1 += -step_size*(dcoeff_1 + lamda*coeff_1)  # coeff_1 - shape(Dxh)
                bias_1 += -step_size * dbias_1
                bias_2 += -step_size * dbias_2
        
        ##### Training Data accuracy #####
        hidden_layer_train = np.maximum(0,np.dot(features,coeff_1)+bias_1)
        scores_train = np.dot(hidden_layer_train,coeff_2)+bias_2
        predicted_class_train = np.argmax(scores_train, axis=1)
        print 'training accuracy: %.4f' % (np.mean(predicted_class_train == labels))
        precision_train,recall_train = confusion_matrix(predicted_class_train,labels)
        print 'training mean precision: %.4f, mean recall: %.4f' % (np.mean(precision_train),np.mean(recall_train))

        ##### Validation Data accuracy #####        
        hidden_layer_valid = np.maximum(0,np.dot(valid_features,coeff_1)+bias_1)
        scores_valid = np.dot(hidden_layer_valid,coeff_2)+bias_2
        predicted_class_valid = np.argmax(scores_valid,axis=1)
        print 'validation accuracy: %.4f' % (np.mean(predicted_class_valid == valid_labels))
        precision_valid,recall_valid = confusion_matrix(predicted_class_valid,valid_labels)
        print 'validation mean precision: %.4f, mean recall: %.4f' % (np.mean(precision_valid),np.mean(recall_valid))   
        
        accuracy += np.mean(predicted_class_valid == valid_labels)
        
    return coeff_1,bias_1,coeff_2,bias_2,tot_cost,accuracy/cross_valid_k

# %%
#features = np.vstack((train_vec_in,valid_features))
#labels = np.concatenate((train_label_out,valid_labels))
#coeff_cv_1,bias_cv_1,coeff_cv_2,bias_cv_2,tot_cost_cv,avg_accuracy = two_layer_nn_sgd_cv(features,labels,hidden_sz=100,\
                                            #cross_valid_k=6,batch_size=200,epoch=20,lamda=0.001,step_size=1,max_iter=100)

# %%
features_cv = np.vstack((train_vec_in,valid_features))
labels_cv = np.concatenate((train_label_out,valid_labels))
lamda = np.logspace(-4,-2,num=10)
for elem in lamda:
    coeff_cv_1,bias_cv_1,coeff_cv_2,bias_cv_2,tot_cost_cv,avg_accuracy = two_layer_nn_sgd_cv(features_cv,labels_cv, \
                                                    hidden_sz=100,cross_valid_k=6, \
                     batch_size=200,epoch=5,lamda=elem,step_size=0.75,max_iter=100)
    print 'AVERAGE ACCURACY OVER VALIDATION SET %f' % avg_accuracy
# Out:
# ------ Training model for batch_size:200, lamda:0.0001, and step_size: 0.7500 ------
# -------------- cross validating set 0 --------------
# training accuracy: 0.9713
# training mean precision: 0.9712, mean recall: 0.9713
# validation accuracy: 0.9601
# validation mean precision: 0.9600, mean recall: 0.9600
# -------------- cross validating set 1 --------------
# training accuracy: 0.9702
# training mean precision: 0.9700, mean recall: 0.9702
# validation accuracy: 0.9595
# validation mean precision: 0.9591, mean recall: 0.9592
# -------------- cross validating set 2 --------------
# training accuracy: 0.9658
# training mean precision: 0.9661, mean recall: 0.9658
# validation accuracy: 0.9564
# validation mean precision: 0.9570, mean recall: 0.9563
# -------------- cross validating set 3 --------------
# training accuracy: 0.9674
# training mean precision: 0.9678, mean recall: 0.9675
# validation accuracy: 0.9610
# validation mean precision: 0.9614, mean recall: 0.9612
# -------------- cross validating set 4 --------------
# training accuracy: 0.9705
# training mean precision: 0.9706, mean recall: 0.9704
# validation accuracy: 0.9595
# validation mean precision: 0.9595, mean recall: 0.9593
# -------------- cross validating set 5 --------------
# training accuracy: 0.9744
# training mean precision: 0.9743, mean recall: 0.9742
# validation accuracy: 0.9702
# validation mean precision: 0.9701, mean recall: 0.9700
# AVERAGE ACCURACY OVER VALIDATION SET 0.961117
# ------ Training model for batch_size:200, lamda:0.0002, and step_size: 0.7500 ------
# -------------- cross validating set 0 --------------
# training accuracy: 0.9728
# training mean precision: 0.9728, mean recall: 0.9728
# validation accuracy: 0.9631
# validation mean precision: 0.9632, mean recall: 0.9628
# -------------- cross validating set 1 --------------
# training accuracy: 0.9697
# training mean precision: 0.9697, mean recall: 0.9696
# validation accuracy: 0.9586
# validation mean precision: 0.9584, mean recall: 0.9580
# -------------- cross validating set 2 --------------
# training accuracy: 0.9677
# training mean precision: 0.9680, mean recall: 0.9678
# validation accuracy: 0.9590
# validation mean precision: 0.9595, mean recall: 0.9589
# -------------- cross validating set 3 --------------
# training accuracy: 0.9729
# training mean precision: 0.9729, mean recall: 0.9729
# validation accuracy: 0.9659
# validation mean precision: 0.9658, mean recall: 0.9659
# -------------- cross validating set 4 --------------
# training accuracy: 0.9723
# training mean precision: 0.9723, mean recall: 0.9723
# validation accuracy: 0.9625
# validation mean precision: 0.9623, mean recall: 0.9623
# -------------- cross validating set 5 --------------
# training accuracy: 0.9755
# training mean precision: 0.9753, mean recall: 0.9754
# validation accuracy: 0.9701
# validation mean precision: 0.9700, mean recall: 0.9699
# AVERAGE ACCURACY OVER VALIDATION SET 0.963200
# ------ Training model for batch_size:200, lamda:0.0003, and step_size: 0.7500 ------
# -------------- cross validating set 0 --------------
# training accuracy: 0.9674
# training mean precision: 0.9675, mean recall: 0.9673
# validation accuracy: 0.9578
# validation mean precision: 0.9580, mean recall: 0.9575
# -------------- cross validating set 1 --------------
# training accuracy: 0.9701
# training mean precision: 0.9700, mean recall: 0.9701
# validation accuracy: 0.9579
# validation mean precision: 0.9576, mean recall: 0.9575
# -------------- cross validating set 2 --------------
# training accuracy: 0.9681
# training mean precision: 0.9681, mean recall: 0.9681
# validation accuracy: 0.9603
# validation mean precision: 0.9604, mean recall: 0.9603
# -------------- cross validating set 3 --------------
# training accuracy: 0.9696
# training mean precision: 0.9697, mean recall: 0.9696
# validation accuracy: 0.9640
# validation mean precision: 0.9642, mean recall: 0.9641
# -------------- cross validating set 4 --------------
# training accuracy: 0.9689
# training mean precision: 0.9691, mean recall: 0.9688
# validation accuracy: 0.9599
# validation mean precision: 0.9602, mean recall: 0.9596
# -------------- cross validating set 5 --------------
# training accuracy: 0.9762
# training mean precision: 0.9761, mean recall: 0.9761
# validation accuracy: 0.9722
# validation mean precision: 0.9721, mean recall: 0.9720
# AVERAGE ACCURACY OVER VALIDATION SET 0.962017
# ------ Training model for batch_size:200, lamda:0.0005, and step_size: 0.7500 ------
# -------------- cross validating set 0 --------------
# training accuracy: 0.9684
# training mean precision: 0.9685, mean recall: 0.9684
# validation accuracy: 0.9581
# validation mean precision: 0.9584, mean recall: 0.9580
# -------------- cross validating set 1 --------------
# training accuracy: 0.9677
# training mean precision: 0.9678, mean recall: 0.9677
# validation accuracy: 0.9573
# validation mean precision: 0.9573, mean recall: 0.9568
# -------------- cross validating set 2 --------------
# training accuracy: 0.9650
# training mean precision: 0.9654, mean recall: 0.9650
# validation accuracy: 0.9582
# validation mean precision: 0.9588, mean recall: 0.9581
# -------------- cross validating set 3 --------------
# training accuracy: 0.9616
# training mean precision: 0.9623, mean recall: 0.9616
# validation accuracy: 0.9556
# validation mean precision: 0.9563, mean recall: 0.9558
# -------------- cross validating set 4 --------------
# training accuracy: 0.9700
# training mean precision: 0.9701, mean recall: 0.9699
# validation accuracy: 0.9612
# validation mean precision: 0.9611, mean recall: 0.9610
# -------------- cross validating set 5 --------------
# training accuracy: 0.9742
# training mean precision: 0.9741, mean recall: 0.9741
# validation accuracy: 0.9702
# validation mean precision: 0.9701, mean recall: 0.9700
# AVERAGE ACCURACY OVER VALIDATION SET 0.960100
# ------ Training model for batch_size:200, lamda:0.0008, and step_size: 0.7500 ------
# -------------- cross validating set 0 --------------
# training accuracy: 0.9618
# training mean precision: 0.9623, mean recall: 0.9619
# validation accuracy: 0.9526
# validation mean precision: 0.9535, mean recall: 0.9525
# -------------- cross validating set 1 --------------
# training accuracy: 0.9658
# training mean precision: 0.9658, mean recall: 0.9658
# validation accuracy: 0.9550
# validation mean precision: 0.9548, mean recall: 0.9546
# -------------- cross validating set 2 --------------
# training accuracy: 0.9555
# training mean precision: 0.9563, mean recall: 0.9555
# validation accuracy: 0.9478
# validation mean precision: 0.9489, mean recall: 0.9478
# -------------- cross validating set 3 --------------
# training accuracy: 0.9646
# training mean precision: 0.9647, mean recall: 0.9646
# validation accuracy: 0.9597
# validation mean precision: 0.9598, mean recall: 0.9598
# -------------- cross validating set 4 --------------
# training accuracy: 0.9618
# training mean precision: 0.9623, mean recall: 0.9619
# validation accuracy: 0.9533
# validation mean precision: 0.9538, mean recall: 0.9533
# -------------- cross validating set 5 --------------
# training accuracy: 0.9715
# training mean precision: 0.9714, mean recall: 0.9713
# validation accuracy: 0.9686
# validation mean precision: 0.9685, mean recall: 0.9683
# AVERAGE ACCURACY OVER VALIDATION SET 0.956167
# ------ Training model for batch_size:200, lamda:0.0013, and step_size: 0.7500 ------
# -------------- cross validating set 0 --------------
# training accuracy: 0.9571
# training mean precision: 0.9576, mean recall: 0.9571
# validation accuracy: 0.9493
# validation mean precision: 0.9502, mean recall: 0.9490
# -------------- cross validating set 1 --------------
# training accuracy: 0.9534
# training mean precision: 0.9543, mean recall: 0.9534
# validation accuracy: 0.9445
# validation mean precision: 0.9455, mean recall: 0.9438
# -------------- cross validating set 2 --------------
# training accuracy: 0.9484
# training mean precision: 0.9499, mean recall: 0.9484
# validation accuracy: 0.9435
# validation mean precision: 0.9451, mean recall: 0.9433
# -------------- cross validating set 3 --------------
# training accuracy: 0.9564
# training mean precision: 0.9571, mean recall: 0.9564
# validation accuracy: 0.9527
# validation mean precision: 0.9536, mean recall: 0.9529
# -------------- cross validating set 4 --------------
# training accuracy: 0.9591
# training mean precision: 0.9595, mean recall: 0.9590
# validation accuracy: 0.9514
# validation mean precision: 0.9517, mean recall: 0.9513
# -------------- cross validating set 5 --------------
# training accuracy: 0.9701
# training mean precision: 0.9699, mean recall: 0.9698
# validation accuracy: 0.9687
# validation mean precision: 0.9686, mean recall: 0.9684
# AVERAGE ACCURACY OVER VALIDATION SET 0.951683
# ------ Training model for batch_size:200, lamda:0.0022, and step_size: 0.7500 ------
# -------------- cross validating set 0 --------------
# training accuracy: 0.9382
# training mean precision: 0.9402, mean recall: 0.9380
# validation accuracy: 0.9292
# validation mean precision: 0.9316, mean recall: 0.9288
# -------------- cross validating set 1 --------------
# training accuracy: 0.9388
# training mean precision: 0.9410, mean recall: 0.9384
# validation accuracy: 0.9311
# validation mean precision: 0.9329, mean recall: 0.9298
# -------------- cross validating set 2 --------------
# training accuracy: 0.9450
# training mean precision: 0.9463, mean recall: 0.9449
# validation accuracy: 0.9386
# validation mean precision: 0.9402, mean recall: 0.9384
# -------------- cross validating set 3 --------------
# training accuracy: 0.9307
# training mean precision: 0.9343, mean recall: 0.9306
# validation accuracy: 0.9288
# validation mean precision: 0.9330, mean recall: 0.9292
# -------------- cross validating set 4 --------------
# training accuracy: 0.9442
# training mean precision: 0.9457, mean recall: 0.9441
# validation accuracy: 0.9394
# validation mean precision: 0.9409, mean recall: 0.9393
# -------------- cross validating set 5 --------------
# training accuracy: 0.9637
# training mean precision: 0.9635, mean recall: 0.9635
# validation accuracy: 0.9651
# validation mean precision: 0.9650, mean recall: 0.9649
# AVERAGE ACCURACY OVER VALIDATION SET 0.938700
# ------ Training model for batch_size:200, lamda:0.0036, and step_size: 0.7500 ------
# -------------- cross validating set 0 --------------
# training accuracy: 0.9333
# training mean precision: 0.9344, mean recall: 0.9326
# validation accuracy: 0.9263
# validation mean precision: 0.9280, mean recall: 0.9255
# -------------- cross validating set 1 --------------
# training accuracy: 0.9301
# training mean precision: 0.9324, mean recall: 0.9292
# validation accuracy: 0.9240
# validation mean precision: 0.9260, mean recall: 0.9224
# -------------- cross validating set 2 --------------
# training accuracy: 0.9299
# training mean precision: 0.9326, mean recall: 0.9295
# validation accuracy: 0.9210
# validation mean precision: 0.9244, mean recall: 0.9204
# -------------- cross validating set 3 --------------
# training accuracy: 0.9324
# training mean precision: 0.9351, mean recall: 0.9320
# validation accuracy: 0.9300
# validation mean precision: 0.9333, mean recall: 0.9301
# -------------- cross validating set 4 --------------
# training accuracy: 0.9223
# training mean precision: 0.9266, mean recall: 0.9220
# validation accuracy: 0.9162
# validation mean precision: 0.9207, mean recall: 0.9156
# -------------- cross validating set 5 --------------
# training accuracy: 0.9558
# training mean precision: 0.9558, mean recall: 0.9554
# validation accuracy: 0.9594
# validation mean precision: 0.9594, mean recall: 0.9591
# AVERAGE ACCURACY OVER VALIDATION SET 0.929483
# ------ Training model for batch_size:200, lamda:0.0060, and step_size: 0.7500 ------
# -------------- cross validating set 0 --------------
# training accuracy: 0.9108
# training mean precision: 0.9134, mean recall: 0.9088
# validation accuracy: 0.9055
# validation mean precision: 0.9084, mean recall: 0.9032
# -------------- cross validating set 1 --------------
# training accuracy: 0.8806
# training mean precision: 0.8926, mean recall: 0.8766
# validation accuracy: 0.8745
# validation mean precision: 0.8850, mean recall: 0.8694
# -------------- cross validating set 2 --------------
# training accuracy: 0.9156
# training mean precision: 0.9190, mean recall: 0.9145
# validation accuracy: 0.9081
# validation mean precision: 0.9122, mean recall: 0.9070
# -------------- cross validating set 3 --------------
# training accuracy: 0.9179
# training mean precision: 0.9197, mean recall: 0.9168
# validation accuracy: 0.9170
# validation mean precision: 0.9194, mean recall: 0.9164
# -------------- cross validating set 4 --------------
# training accuracy: 0.9031
# training mean precision: 0.9108, mean recall: 0.9029
# validation accuracy: 0.8963
# validation mean precision: 0.9046, mean recall: 0.8960
# -------------- cross validating set 5 --------------
# training accuracy: 0.9429
# training mean precision: 0.9428, mean recall: 0.9424
# validation accuracy: 0.9455
# validation mean precision: 0.9454, mean recall: 0.9452
# AVERAGE ACCURACY OVER VALIDATION SET 0.907817
# ------ Training model for batch_size:200, lamda:0.0100, and step_size: 0.7500 ------
# -------------- cross validating set 0 --------------
# training accuracy: 0.8923
# training mean precision: 0.8975, mean recall: 0.8910
# validation accuracy: 0.8873
# validation mean precision: 0.8927, mean recall: 0.8851
# -------------- cross validating set 1 --------------
# training accuracy: 0.8800
# training mean precision: 0.8900, mean recall: 0.8795
# validation accuracy: 0.8753
# validation mean precision: 0.8847, mean recall: 0.8738
# -------------- cross validating set 2 --------------
# training accuracy: 0.8918
# training mean precision: 0.8972, mean recall: 0.8905
# validation accuracy: 0.8853
# validation mean precision: 0.8919, mean recall: 0.8841
# -------------- cross validating set 3 --------------
# training accuracy: 0.8904
# training mean precision: 0.8942, mean recall: 0.8884
# validation accuracy: 0.8889
# validation mean precision: 0.8926, mean recall: 0.8870
# -------------- cross validating set 4 --------------
# training accuracy: 0.8819
# training mean precision: 0.8894, mean recall: 0.8795
# validation accuracy: 0.8728
# validation mean precision: 0.8815, mean recall: 0.8697
# -------------- cross validating set 5 --------------
# training accuracy: 0.9144
# training mean precision: 0.9168, mean recall: 0.9142
# validation accuracy: 0.9224
# validation mean precision: 0.9245, mean recall: 0.9225
# AVERAGE ACCURACY OVER VALIDATION SET 0.888667
# C:\Users\GAURAV\Anaconda2\lib\site-packages\ipykernel\__main__.py:53: RuntimeWarning: invalid value encountered in double_scalars

# %%
step_size = np.logspace(-1,0.5,num=10)
for elem in step_size:
    coeff_cv_1,bias_cv_1,coeff_cv_2,bias_cv_2,tot_cost_cv,avg_accuracy = two_layer_nn_sgd_cv(features,labels,hidden_sz=100,\
                                cross_valid_k=6,batch_size=200,epoch=5,lamda=0.0002,step_size=elem,max_iter=100)
    print 'AVERAGE ACCURACY OVER VALIDATION SET %f' % avg_accuracy
# Out:
# Training model for batch_size:200, lamda:0.0002, and step_size: 0.1000
# $$$$$$$$$$$$$ cross validating set 0 $$$$$$$$$$$$$$
# training accuracy: 0.9187
# training mean precision: 0.9184, mean recall: 0.9179
# validation accuracy: 0.9143
# validation mean precision: 0.9135, mean recall: 0.9129
# $$$$$$$$$$$$$ cross validating set 1 $$$$$$$$$$$$$$
# training accuracy: 0.9447
# training mean precision: 0.9445, mean recall: 0.9443
# validation accuracy: 0.9417
# validation mean precision: 0.9413, mean recall: 0.9412
# $$$$$$$$$$$$$ cross validating set 2 $$$$$$$$$$$$$$
# training accuracy: 0.9577
# training mean precision: 0.9574, mean recall: 0.9574
# validation accuracy: 0.9547
# validation mean precision: 0.9542, mean recall: 0.9542
# $$$$$$$$$$$$$ cross validating set 3 $$$$$$$$$$$$$$
# training accuracy: 0.9643
# training mean precision: 0.9641, mean recall: 0.9641
# validation accuracy: 0.9565
# validation mean precision: 0.9566, mean recall: 0.9563
# $$$$$$$$$$$$$ cross validating set 4 $$$$$$$$$$$$$$
# training accuracy: 0.9695
# training mean precision: 0.9694, mean recall: 0.9694
# validation accuracy: 0.9649
# validation mean precision: 0.9647, mean recall: 0.9648
# $$$$$$$$$$$$$ cross validating set 5 $$$$$$$$$$$$$$
# training accuracy: 0.9742
# training mean precision: 0.9743, mean recall: 0.9741
# validation accuracy: 0.9739
# validation mean precision: 0.9740, mean recall: 0.9735
# AVERAGE ACCURACY OVER VALIDATION SET 0.951000
# Training model for batch_size:200, lamda:0.0002, and step_size: 0.1468
# $$$$$$$$$$$$$ cross validating set 0 $$$$$$$$$$$$$$
# training accuracy: 0.9285
# training mean precision: 0.9286, mean recall: 0.9278
# validation accuracy: 0.9218
# validation mean precision: 0.9214, mean recall: 0.9206
# $$$$$$$$$$$$$ cross validating set 1 $$$$$$$$$$$$$$
# training accuracy: 0.9553
# training mean precision: 0.9551, mean recall: 0.9550
# validation accuracy: 0.9508
# validation mean precision: 0.9505, mean recall: 0.9504
# $$$$$$$$$$$$$ cross validating set 2 $$$$$$$$$$$$$$
# training accuracy: 0.9668
# training mean precision: 0.9666, mean recall: 0.9667
# validation accuracy: 0.9619
# validation mean precision: 0.9616, mean recall: 0.9616
# $$$$$$$$$$$$$ cross validating set 3 $$$$$$$$$$$$$$
# training accuracy: 0.9736
# training mean precision: 0.9734, mean recall: 0.9735
# validation accuracy: 0.9655
# validation mean precision: 0.9656, mean recall: 0.9655
# $$$$$$$$$$$$$ cross validating set 4 $$$$$$$$$$$$$$
# training accuracy: 0.9778
# training mean precision: 0.9776, mean recall: 0.9777
# validation accuracy: 0.9741
# validation mean precision: 0.9740, mean recall: 0.9741
# $$$$$$$$$$$$$ cross validating set 5 $$$$$$$$$$$$$$
# training accuracy: 0.9822
# training mean precision: 0.9822, mean recall: 0.9821
# validation accuracy: 0.9813
# validation mean precision: 0.9813, mean recall: 0.9812
# AVERAGE ACCURACY OVER VALIDATION SET 0.959233
# Training model for batch_size:200, lamda:0.0002, and step_size: 0.2154
# $$$$$$$$$$$$$ cross validating set 0 $$$$$$$$$$$$$$
# training accuracy: 0.9452
# training mean precision: 0.9451, mean recall: 0.9448
# validation accuracy: 0.9371
# validation mean precision: 0.9365, mean recall: 0.9362
# $$$$$$$$$$$$$ cross validating set 1 $$$$$$$$$$$$$$
# training accuracy: 0.9669
# training mean precision: 0.9667, mean recall: 0.9667
# validation accuracy: 0.9619
# validation mean precision: 0.9616, mean recall: 0.9614
# $$$$$$$$$$$$$ cross validating set 2 $$$$$$$$$$$$$$
# training accuracy: 0.9760
# training mean precision: 0.9759, mean recall: 0.9759
# validation accuracy: 0.9707
# validation mean precision: 0.9704, mean recall: 0.9704
# $$$$$$$$$$$$$ cross validating set 3 $$$$$$$$$$$$$$
# training accuracy: 0.9808
# training mean precision: 0.9807, mean recall: 0.9807
# validation accuracy: 0.9728
# validation mean precision: 0.9728, mean recall: 0.9728
# $$$$$$$$$$$$$ cross validating set 4 $$$$$$$$$$$$$$
# training accuracy: 0.9838
# training mean precision: 0.9837, mean recall: 0.9838
# validation accuracy: 0.9792
# validation mean precision: 0.9790, mean recall: 0.9792
# $$$$$$$$$$$$$ cross validating set 5 $$$$$$$$$$$$$$
# training accuracy: 0.9867
# training mean precision: 0.9867, mean recall: 0.9866
# validation accuracy: 0.9837
# validation mean precision: 0.9837, mean recall: 0.9835
# AVERAGE ACCURACY OVER VALIDATION SET 0.967567
# Training model for batch_size:200, lamda:0.0002, and step_size: 0.3162
# $$$$$$$$$$$$$ cross validating set 0 $$$$$$$$$$$$$$
# training accuracy: 0.9567
# training mean precision: 0.9568, mean recall: 0.9563
# validation accuracy: 0.9468
# validation mean precision: 0.9467, mean recall: 0.9461
# $$$$$$$$$$$$$ cross validating set 1 $$$$$$$$$$$$$$
# training accuracy: 0.9747
# training mean precision: 0.9746, mean recall: 0.9746
# validation accuracy: 0.9698
# validation mean precision: 0.9696, mean recall: 0.9695
# $$$$$$$$$$$$$ cross validating set 2 $$$$$$$$$$$$$$
# training accuracy: 0.9812
# training mean precision: 0.9812, mean recall: 0.9811
# validation accuracy: 0.9747
# validation mean precision: 0.9746, mean recall: 0.9744
# $$$$$$$$$$$$$ cross validating set 3 $$$$$$$$$$$$$$
# training accuracy: 0.9852
# training mean precision: 0.9852, mean recall: 0.9852
# validation accuracy: 0.9772
# validation mean precision: 0.9772, mean recall: 0.9772
# $$$$$$$$$$$$$ cross validating set 4 $$$$$$$$$$$$$$
# training accuracy: 0.9884
# training mean precision: 0.9883, mean recall: 0.9884
# validation accuracy: 0.9827
# validation mean precision: 0.9826, mean recall: 0.9828
# $$$$$$$$$$$$$ cross validating set 5 $$$$$$$$$$$$$$
# training accuracy: 0.9899
# training mean precision: 0.9899, mean recall: 0.9898
# validation accuracy: 0.9872
# validation mean precision: 0.9873, mean recall: 0.9870
# AVERAGE ACCURACY OVER VALIDATION SET 0.973067
# Training model for batch_size:200, lamda:0.0002, and step_size: 0.4642
# $$$$$$$$$$$$$ cross validating set 0 $$$$$$$$$$$$$$
# training accuracy: 0.9634
# training mean precision: 0.9635, mean recall: 0.9632
# validation accuracy: 0.9527
# validation mean precision: 0.9528, mean recall: 0.9523
# $$$$$$$$$$$$$ cross validating set 1 $$$$$$$$$$$$$$
# training accuracy: 0.9786
# training mean precision: 0.9784, mean recall: 0.9785
# validation accuracy: 0.9724
# validation mean precision: 0.9722, mean recall: 0.9721
# $$$$$$$$$$$$$ cross validating set 2 $$$$$$$$$$$$$$
# training accuracy: 0.9852
# training mean precision: 0.9851, mean recall: 0.9852
# validation accuracy: 0.9797
# validation mean precision: 0.9794, mean recall: 0.9796
# $$$$$$$$$$$$$ cross validating set 3 $$$$$$$$$$$$$$
# training accuracy: 0.9884
# training mean precision: 0.9882, mean recall: 0.9884
# validation accuracy: 0.9788
# validation mean precision: 0.9787, mean recall: 0.9788
# $$$$$$$$$$$$$ cross validating set 4 $$$$$$$$$$$$$$
# training accuracy: 0.9907
# training mean precision: 0.9906, mean recall: 0.9907
# validation accuracy: 0.9834
# validation mean precision: 0.9832, mean recall: 0.9835
# $$$$$$$$$$$$$ cross validating set 5 $$$$$$$$$$$$$$
# training accuracy: 0.9925
# training mean precision: 0.9925, mean recall: 0.9925
# validation accuracy: 0.9891
# validation mean precision: 0.9891, mean recall: 0.9890
# AVERAGE ACCURACY OVER VALIDATION SET 0.976017
# Training model for batch_size:200, lamda:0.0002, and step_size: 0.6813
# $$$$$$$$$$$$$ cross validating set 0 $$$$$$$$$$$$$$
# training accuracy: 0.9711
# training mean precision: 0.9713, mean recall: 0.9710
# validation accuracy: 0.9611
# validation mean precision: 0.9612, mean recall: 0.9607
# $$$$$$$$$$$$$ cross validating set 1 $$$$$$$$$$$$$$
# training accuracy: 0.9829
# training mean precision: 0.9829, mean recall: 0.9828
# validation accuracy: 0.9756
# validation mean precision: 0.9756, mean recall: 0.9754
# $$$$$$$$$$$$$ cross validating set 2 $$$$$$$$$$$$$$
# training accuracy: 0.9872
# training mean precision: 0.9872, mean recall: 0.9873
# validation accuracy: 0.9818
# validation mean precision: 0.9816, mean recall: 0.9816
# $$$$$$$$$$$$$ cross validating set 3 $$$$$$$$$$$$$$
# training accuracy: 0.9896
# training mean precision: 0.9896, mean recall: 0.9897
# validation accuracy: 0.9818
# validation mean precision: 0.9817, mean recall: 0.9818
# $$$$$$$$$$$$$ cross validating set 4 $$$$$$$$$$$$$$
# training accuracy: 0.9904
# training mean precision: 0.9904, mean recall: 0.9905
# validation accuracy: 0.9842
# validation mean precision: 0.9841, mean recall: 0.9842
# $$$$$$$$$$$$$ cross validating set 5 $$$$$$$$$$$$$$
# training accuracy: 0.9931
# training mean precision: 0.9932, mean recall: 0.9931
# validation accuracy: 0.9895
# validation mean precision: 0.9895, mean recall: 0.9893
# AVERAGE ACCURACY OVER VALIDATION SET 0.979000
# Training model for batch_size:200, lamda:0.0002, and step_size: 1.0000
# $$$$$$$$$$$$$ cross validating set 0 $$$$$$$$$$$$$$
# training accuracy: 0.9623
# training mean precision: 0.9628, mean recall: 0.9624
# validation accuracy: 0.9524
# validation mean precision: 0.9528, mean recall: 0.9522
# $$$$$$$$$$$$$ cross validating set 1 $$$$$$$$$$$$$$
# training accuracy: 0.9717
# training mean precision: 0.9717, mean recall: 0.9718
# validation accuracy: 0.9627
# validation mean precision: 0.9628, mean recall: 0.9626
# $$$$$$$$$$$$$ cross validating set 2 $$$$$$$$$$$$$$
# training accuracy: 0.9762
# training mean precision: 0.9762, mean recall: 0.9764
# validation accuracy: 0.9695
# validation mean precision: 0.9695, mean recall: 0.9696
# $$$$$$$$$$$$$ cross validating set 3 $$$$$$$$$$$$$$
# training accuracy: 0.9804
# training mean precision: 0.9803, mean recall: 0.9805
# validation accuracy: 0.9694
# validation mean precision: 0.9694, mean recall: 0.9696
# $$$$$$$$$$$$$ cross validating set 4 $$$$$$$$$$$$$$
# training accuracy: 0.9829
# training mean precision: 0.9829, mean recall: 0.9831
# validation accuracy: 0.9746
# validation mean precision: 0.9747, mean recall: 0.9747
# $$$$$$$$$$$$$ cross validating set 5 $$$$$$$$$$$$$$
# training accuracy: 0.9869
# training mean precision: 0.9870, mean recall: 0.9867
# validation accuracy: 0.9812
# validation mean precision: 0.9813, mean recall: 0.9810
# AVERAGE ACCURACY OVER VALIDATION SET 0.968300
# Training model for batch_size:200, lamda:0.0002, and step_size: 1.4678
# $$$$$$$$$$$$$ cross validating set 0 $$$$$$$$$$$$$$
# training accuracy: 0.1045
# C:\Users\GAURAV\Anaconda2\lib\site-packages\ipykernel\__main__.py:53: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\GAURAV\Anaconda2\lib\site-packages\ipykernel\__main__.py:11: RuntimeWarning: invalid value encountered in double_scalars
# training mean precision: nan, mean recall: 0.1001
# validation accuracy: 0.1030
# validation mean precision: nan, mean recall: 0.1000
# $$$$$$$$$$$$$ cross validating set 1 $$$$$$$$$$$$$$
# training accuracy: 0.1044
# training mean precision: nan, mean recall: 0.1000
# validation accuracy: 0.1017
# validation mean precision: nan, mean recall: 0.1000
# $$$$$$$$$$$$$ cross validating set 2 $$$$$$$$$$$$$$
# training accuracy: 0.1044
# training mean precision: nan, mean recall: 0.1000
# validation accuracy: 0.1068
# validation mean precision: nan, mean recall: 0.1000
# $$$$$$$$$$$$$ cross validating set 3 $$$$$$$$$$$$$$
# training accuracy: 0.1044
# training mean precision: nan, mean recall: 0.1000
# validation accuracy: 0.1060
# validation mean precision: nan, mean recall: 0.1000
# $$$$$$$$$$$$$ cross validating set 4 $$$$$$$$$$$$$$
# training accuracy: 0.1044
# training mean precision: nan, mean recall: 0.1000
# validation accuracy: 0.1000
# validation mean precision: nan, mean recall: 0.1000
# $$$$$$$$$$$$$ cross validating set 5 $$$$$$$$$$$$$$
# training accuracy: 0.1044
# training mean precision: nan, mean recall: 0.1000
# validation accuracy: 0.1090
# validation mean precision: nan, mean recall: 0.1000
# AVERAGE ACCURACY OVER VALIDATION SET 0.104417
# Training model for batch_size:200, lamda:0.0002, and step_size: 2.1544
# $$$$$$$$$$$$$ cross validating set 0 $$$$$$$$$$$$$$
# training accuracy: 0.1044
# training mean precision: nan, mean recall: 0.1000
# validation accuracy: 0.1030
# validation mean precision: nan, mean recall: 0.1000
# $$$$$$$$$$$$$ cross validating set 1 $$$$$$$$$$$$$$
# training accuracy: 0.1044
# training mean precision: nan, mean recall: 0.1000
# validation accuracy: 0.1017
# validation mean precision: nan, mean recall: 0.1000
# $$$$$$$$$$$$$ cross validating set 2 $$$$$$$$$$$$$$
# training accuracy: 0.1044
# training mean precision: nan, mean recall: 0.1000
# validation accuracy: 0.1068
# validation mean precision: nan, mean recall: 0.1000
# $$$$$$$$$$$$$ cross validating set 3 $$$$$$$$$$$$$$
# training accuracy: 0.1044
# training mean precision: nan, mean recall: 0.1000
# validation accuracy: 0.1060
# validation mean precision: nan, mean recall: 0.1000
# $$$$$$$$$$$$$ cross validating set 4 $$$$$$$$$$$$$$
# training accuracy: 0.1044
# training mean precision: nan, mean recall: 0.1000
# validation accuracy: 0.1000
# validation mean precision: nan, mean recall: 0.1000
# $$$$$$$$$$$$$ cross validating set 5 $$$$$$$$$$$$$$
# training accuracy: 0.1044
# training mean precision: nan, mean recall: 0.1000
# validation accuracy: 0.1090
# validation mean precision: nan, mean recall: 0.1000
# AVERAGE ACCURACY OVER VALIDATION SET 0.104417
# Training model for batch_size:200, lamda:0.0002, and step_size: 3.1623
# $$$$$$$$$$$$$ cross validating set 0 $$$$$$$$$$$$$$
# training accuracy: 0.1044
# training mean precision: nan, mean recall: 0.1000
# validation accuracy: 0.1030
# validation mean precision: nan, mean recall: 0.1000
# $$$$$$$$$$$$$ cross validating set 1 $$$$$$$$$$$$$$
# training accuracy: 0.1044
# training mean precision: nan, mean recall: 0.1000
# validation accuracy: 0.1017
# validation mean precision: nan, mean recall: 0.1000
# $$$$$$$$$$$$$ cross validating set 2 $$$$$$$$$$$$$$
# training accuracy: 0.1044
# training mean precision: nan, mean recall: 0.1000
# validation accuracy: 0.1068
# validation mean precision: nan, mean recall: 0.1000
# $$$$$$$$$$$$$ cross validating set 3 $$$$$$$$$$$$$$
# training accuracy: 0.1044
# training mean precision: nan, mean recall: 0.1000
# validation accuracy: 0.1060
# validation mean precision: nan, mean recall: 0.1000
# $$$$$$$$$$$$$ cross validating set 4 $$$$$$$$$$$$$$
# training accuracy: 0.1044
# training mean precision: nan, mean recall: 0.1000
# validation accuracy: 0.1000
# validation mean precision: nan, mean recall: 0.1000
# $$$$$$$$$$$$$ cross validating set 5 $$$$$$$$$$$$$$
# training accuracy: 0.1044
# training mean precision: nan, mean recall: 0.1000
# validation accuracy: 0.1090
# validation mean precision: nan, mean recall: 0.1000
# AVERAGE ACCURACY OVER VALIDATION SET 0.104417
